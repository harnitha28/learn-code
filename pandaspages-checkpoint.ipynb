# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([101,201,301,],
           index=['A','B','C'])
print(s)
# Out:
# A    101
# B    201
# C    301
# dtype: int64

# %%
data={
    'Maths':88,
    'Chemistry':90,
    'Physics':85}
s=pd.Series(data)
print(s)
# Out:
# Maths        88
# Chemistry    90
# Physics      85
# dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s[1])
# Out:
# 20

# %%
s=pd.Series([101,202,301,401],
            index=['A','B','C','D'])
print(s['B'])
# Out:
# 202

# %%
print(s[['A','C']])
# Out:
# A    101
# C    301
# dtype: int64

# %%
print(s.size)
# Out:
# 4

# %%
print(s.shape)
# Out:
# (4,)

# %%
print(s.dtype)
# Out:
# int64

# %%
s=pd.Series([101,201,301,401])
print(s+11)
# Out:
# 0    112
# 1    212
# 2    312
# 3    412
# dtype: int64

# %%
print(s*2)
# Out:
# 0    202
# 1    402
# 2    602
# 3    802
# dtype: int64

# %%
print("Sum=",s.sum())
print("Mean=",s.mean())
print("Maximun=",s.max())
print("Minimum=",s.min())
# Out:
# Sum= 1004
# Mean= 251.0
# Maximun= 401
# Minimum= 101

# %%
data={
    'RollNO':[101,201,301],
    'Name':['Arun','priya','rahul'],
    'Marks':[85,88,89]}
df=pd.DataFrame(data)
print(df)
# Out:
#    RollNO   Name  Marks
# 0     101   Arun     85
# 1     201  priya     88
# 2     301  rahul     89

# %%
df=pd.DataFrame(data,
                index=['A','B','C'])
print(df)
# Out:
#    RollNO   Name  Marks
# A     101   Arun     85
# B     201  priya     88
# C     301  rahul     89

# %%
print(df.size)
# Out:
# 9

# %%
print(df.columns)
# Out:
# Index(['RollNO', 'Name', 'Marks'], dtype='object')

# %%
print(df.shape)
# Out:
# (3, 3)
