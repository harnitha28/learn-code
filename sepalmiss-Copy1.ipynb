# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Ibscai25.DGVC-MCA/Desktop/IBSCAI25/dv sem2/book1.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    8
# sepal_width     7
# petal_length    7
# petal_width     7
# class           0
# dtype: int64

# %%
df['sepal_length']=df['sepal_length'].fillna(9)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     7
# petal_length    7
# petal_width     7
# class           0
# dtype: int64

# %%
hs=df['sepal_width'].mean()
hs
# Out:
# np.float64(3.0605633802816903)

# %%
hs=df['sepal_width']=df['sepal_width'].fillna(hs)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    7
# petal_width     7
# class           0
# dtype: int64

# %%
mn=df['petal_length'].median()
mn
# Out:
# 4.4

# %%
mn=df['petal_length']=df['petal_length'].fillna(mn)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     7
# class           0
# dtype: int64

# %%
ss=df['petal_width'].mode()[0]
ss
# Out:
# np.float64(0.2)

# %%
mn=df['petal_width']=df['petal_width'].fillna(ss)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
import matplotlib.pyplot as plt 
import pandas as pd
df=pd.read_csv("C:/Users/Ibscai25.DGVC-MCA/Desktop/IBSCAI25/dv sem2/book1.csv")
x=df["sepal_length"]
y=df["sepal_width"]
x1=df["petal_length"]
y1=df["petal_width"]
plt.xlabel("sepal")
plt.ylabel("petal")
plt.title("Sepal and Petal")
plt.plot(x,y,label="Line-1",color='brown',linestyle='dashdot',linewidth=3,marker='.',markerfacecolor='grey',markersize=12)
plt.plot(x1,y1,label="Line-2",color='green',linestyle='dotted')
plt.legend()
plt.savefig("sepal.png")
plt.show()

# %%
import matplotlib.pyplot as plt 
import pandas as pd
df=pd.read_csv("C:/Users/Ibscai25.DGVC-MCA/Desktop/IBSCAI25/dv sem2/book1.csv")
x=df["sepal_length"]
y=df["sepal_width"]
plt.xlabel("sepal")
plt.ylabel("petal")
plt.title("Sepal and Petal")
plt.scatter(x,y,label="Line-1",color='brown',linestyle='dashdot',linewidth=3,marker='*')
plt.legend()
plt.savefig("sepal.png")
plt.show()

# %%
import matplotlib.pyplot as plt 
import pandas as pd
df=pd.read_csv("C:/Users/Ibscai25.DGVC-MCA/Desktop/IBSCAI25/dv sem2/book1.csv")
x=df["sepal_length"]
y=df["sepal_width"]
plt.xlabel("sepal")
plt.ylabel("petal")
plt.title("Sepal and Petal")
plt.bar(x,y,color="green",width=0.3,edgecolor="black")
plt.show()

# %%
plt.hist(df["sepal_length"])
# Out:
# (array([ 8., 23., 13., 25., 16., 24., 17.,  5.,  4.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
mk=pd.Series(df["sepal_length"])
mk
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    NaN
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sepal_length, Length: 149, dtype: float64

# %%
mk.plot(kind="density",color="red",linewidth=2,linestyle="--",label="sepal_length")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.subplot(1,2,2)
mk.plot(kind="density")
plt.subplot(2,2,2)
plt.hist("sepal_length")
plt.subplot(2,2,3)
plt.scatter(hours,mks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.subplot(1,2,2)
#       2 mk.plot(kind="density")
#       3 plt.subplot(2,2,2)
#
# NameError: name 'plt' is not defined
