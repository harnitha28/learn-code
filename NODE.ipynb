# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None
class mystack:
    def __init__(self):
        self.top = None
        self.count = 0
    def push(self, x):
        temp = Node(x)
        temp.next = self.top
        self.top = temp
        self.count += 1
    def pop(self):
        if self.top is None:
            print("Stack underflow")
            return -1
        temp = self.top
        self.top = self.top.next
        self.count -= 1
        return temp.data
    def peek(self):
        if self.top is None:
            print("Stack is empty")
            return -1
        return self.top.data
    def isEmpty(self):
        return self.top is None
    def size(self):
        return self.count
st = mystack()
n = int(input("Enter the no of elements to push: "))
for i in range(n):
    x = int(input(f"Enter element {i+1}: "))
    st.push(x)
print("Popped element:", st.pop())
print("Top element:", st.peek())
if st.isEmpty():
    print("Stack is Empty")
else:
    print("Stack is not Empty")
print("Current size:", st.size())
# Out:
# Enter the no of elements to push:  3
# Enter element 1:  4
# Enter element 2:  5
# Enter element 3:  6
# Popped element: 6
# Top element: 5
# Stack is not Empty
# Current size: 2
