# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Ibscai25.DGVC-MCA/Desktop/IBSCAI25/dv sem2/hcv.csv")
df.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP           18
# ALT            1
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %%
df['ALT']=df['ALT'].fillna(9)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP           18
# ALT            0
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %%
hs=df['ALP'].mean()
hs
# Out:
# np.float64(68.28391959798995)

# %%
hs=df['ALP']=df['ALP'].fillna(hs)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP            0
# ALT            0
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %%
mn=df['ALB'].median()
mn
# Out:
# 41.95

# %%
mn=df['CHOL']=df['CHOL'].fillna(mn)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           1
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          1
# dtype: int64

# %%
ss=df['ALB'].mode()[0]
ss
# Out:
# np.float64(39.0)

# %%
mn=df['ALB']=df['ALB'].fillna(ss)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           0
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          1
# dtype: int64

# %%
Ss=df['PROT'].mean()
Ss
# Out:
# np.float64(72.0441368078176)

# %%
Ss=df['PROT']=df['PROT'].fillna(Ss)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           0
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          0
# dtype: int64
